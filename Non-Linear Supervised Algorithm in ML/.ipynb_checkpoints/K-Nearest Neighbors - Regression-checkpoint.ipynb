# %%
# K-Nearest Neighbors - Regression

# %%
# 1. Manhattan Distance L1
# 2. Euclidean Distance L2

# L1 = |x2 - x1| + |y2 - y1|
# L2 = √(x2 - x1)^2 + (y2 - y1)^2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv("multiple_linear_regression_dataset.csv")
dataset.head(3)
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580

# %%
dataset.shape
# Out:
# (20, 3)

# %%
dataset.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
x = dataset.drop(columns = "income")
x
# Out:
#     age  experience
# 0    25           1
# 1    30           3
# 2    47           2
# 3    32           5
# 4    43          10
# 5    51           7
# 6    28           5
# 7    33           4
# 8    37           5
# 9    39           8
# 10   29           1
# 11   47           9
# 12   54           5
# 13   51           4
# 14   44          12
# 15   41           6
# 16   58          17
# 17   23           1
# 18   44           9
# 19   37          10

# %%
y = dataset["income"]
y
# Out:
# 0     30450
# 1     35670
# 2     31580
# 3     40130
# 4     47830
# 5     41630
# 6     41340
# 7     37650
# 8     40250
# 9     45150
# 10    27840
# 11    46110
# 12    36720
# 13    34800
# 14    51300
# 15    38900
# 16    63600
# 17    30870
# 18    44190
# 19    48700
# Name: income, dtype: int64

# %%
sns.scatterplot(x="age", y="experience", data=dataset, hue="income")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x), columns=x.columns)
x
# Out:
#          age  experience
# 0  -1.498903   -1.293548
# 1  -0.987332   -0.796030
# 2   0.752009   -1.044789
# 3  -0.782703   -0.298511
# 4   0.342752    0.945285
# 5   1.161266    0.199007
# 6  -1.191960   -0.298511
# 7  -0.680389   -0.547270
# 8  -0.271133   -0.298511
# 9  -0.066504    0.447767
# 10 -1.089646   -1.293548
# 11  0.752009    0.696526
# 12  1.468208   -0.298511
# 13  1.161266   -0.547270
# 14  0.445067    1.442804
# 15  0.138124   -0.049752
# 16  1.877465    2.686600
# 17 -1.703531   -1.293548
# 18  0.445067    0.696526
# 19 -0.271133    0.945285

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
knn.score(x_train, y_train)*100
# Out:
# 78.96638707209125

# %%
knn.score(x_test, y_test)*100
# Out:
# 77.37621608056908

# %%
for i in range(1, 15):
    knn = KNeighborsRegressor(n_neighbors=i)
    knn.fit(x_train, y_train)
    print(i, knn.score(x_train, y_train), knn.score(x_test, y_test))
# Out:
# 1 1.0 0.7847802116974187
# 2 0.9364877471431888 0.8844169531001999
# 3 0.8511493799037483 0.8076337642449479
# 4 0.7896638707209125 0.7737621608056908
# 5 0.7087723611247356 0.7438411681842672
# 6 0.6415506025706398 0.6124650823341117
# 7 0.5379255916997443 0.5454227770661717
# 8 0.5021815118045164 0.4329672804246154
# 9 0.409428121264522 0.4051456326767118
# 10 0.39261046175287573 0.3030302534839988
# 11 0.33855155609263876 0.36606564063760905
# 12 0.29186537719878225 0.22083519367744597
# 13 0.2512493088113328 0.1433702515429639
# 14 0.26678144815428895 0.12611675059410954

# %%
knn.predict([[1.083596, -0.990844]])
# Out:
# C:\Users\PRANAV\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([37667.5])
