# %%
# Unsupervised Learning - input data present but output not present

# %%
# Unsupervised Learning types
# 1. Clustering
# 2. Association

# %%
# Unsupervised Learning Algorithms:
# K-means clustering
# Hierarchal clustering
# DBSCAN clustering
# Apriori algorithm / f growth
# Principle Component Analysis
