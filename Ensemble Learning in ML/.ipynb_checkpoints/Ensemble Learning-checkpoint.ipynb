# %%
# Ensemble Learning

# %%
# Ensemble Learning type
# 1. Bagging
# 2. Boosting

# %%
# Basic Ensemble-Techniques
# Max Voting
# Averaging
# Weighted Average

# %%
# Advanced Ensemble Techniques
# Stacking
# Blending
# Bagging
# Boosting

# %%
# Algorithms based on Bagging and Boosting
# 1. Bagging algorithms:
# Bagging meta-estimator
# Random forest
    
# 2. Boosting algorithms:
# AdaBoost
# GBM
# XGBM
# Light GBM
# CatBoost
