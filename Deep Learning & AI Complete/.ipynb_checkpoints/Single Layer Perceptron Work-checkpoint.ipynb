# %%
# Perceptron Work

# %%
# Single Layer Perceptron Work

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv("placements.csv")
dataset.head(3)
# Out:
#    cgpa  score  placement
# 0   6.8   6.15          1
# 1   5.9   5.30          0
# 2   5.3   6.05          0

# %%
plt.figure(figsize=(4, 3))
sns.scatterplot(x="cgpa", y="score", data=dataset, hue="placement")
plt.show()

# %%
x = dataset.iloc[:, :-1]
x
# Out:
#     cgpa  score
# 0    6.8   6.15
# 1    5.9   5.30
# 2    5.3   6.05
# 3    7.4   6.60
# 4    5.8   7.10
# ..   ...    ...
# 95   4.3  10.00
# 96   4.4   2.10
# 97   6.7   9.10
# 98   6.3   5.15
# 99   6.2   5.65
#
# [100 rows x 2 columns]

# %%
y = dataset["placement"]
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10)

# %%
from sklearn.linear_model import Perceptron

# %%
pr = Perceptron()
pr.fit(x_train, y_train)
# Out:
# Perceptron()

# %%
pr.score(x_train, y_train)*100, pr.score(x_test, y_test)*100
# Out:
# (81.25, 70.0)

# %%
plt.figure(figsize=(4, 3))
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf=pr)
plt.show()
# Out:
# C:\Users\PRANAV\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(

# %%
# https://playground.tensorflow.org
