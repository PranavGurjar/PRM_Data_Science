# %%
# Forward Propagation And Back Propagation

# %% [markdown]
# # Forward Propagation

# %%
# Forward Propagation

# y^ = σ(ωTx+b)

# Explanation:
# 𝑦 → Predicted output
# σ → Activation function (usually sigmoid)
# 𝜔𝑇 → Transpose of weight vector
# x → Input features
# b → Bias term

# %% [markdown]
# # Back Propagation

# %%
# Back Propagation

# Gradient Descent

# w=w−η⋅∂w/∂L

# w = weight
# η = learning rate
# L = loss function
