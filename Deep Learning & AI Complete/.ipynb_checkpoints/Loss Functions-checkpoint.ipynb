# %%
# Loss Functions

# %%
# loss = (y - y_prd)

# %%
# Loss Functions

# 1. Regression:
# MSE (Mean Squared Error)
# MAE (Mean Absolute Error)
# Hubber loss

# 2. Classification:
# Binary cross-entropy
# Categorical cross-entropy

# 3. Auto Encoder:
# KL Divergence

# 4. GAN:
# Discriminator loss
# Minmax GAN loss

# 5. Object detection:
# Focal loss

# 6. Word embeddings:
# Triplet loss
